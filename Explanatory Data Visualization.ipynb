# %% [markdown]
# # Part II - (Explanatory Data Visualization)
# ## by (Garba Hassan Usman)

# %% [markdown]
# ## Investigation Overview
#
#
# > In this investigation, I wanted to look at the factors that affect a loan's outcome status, What affects the borrower’s APR or interest rate, and to see if there are differences between loans depending on how large the original loan amount was?
#
# > Through the visualizations I observed the following:
#
# > The BorrowerRate rises for loans with longer terms at every level of ProsperRating. Given that loans with shorter terms typically have higher interest rates, I would anticipate the opposite. This is a little surprising because it was not at all obvious in the bivariate analysis.
#
# > According to the visualization, the borrower's APR has a wide range of values depending on the size of the total loan amount, but the range of APR diminishes as the loan amount rises. Therefore, there is a bad correlation between the borrower's APR and the overall loan amount.
#
# > The lender yield and borrower APR have a straight positive inverse relationship, with the lender yield rising as the borrower pays more interest. Lower borrower interest rates and hence lower lender yields result with higher credit scores.

# %% [markdown]
# ## Dataset Overview
#
# > This data set contains 113,937 loans with 81 variables on each loan, including loan amount, borrower rate (or interest rate), current loan status, borrower income, and many others. Some of these variables are numerical while some are categorical.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
loan = pd.read_csv('prosperLoanData.csv')

# %%
# Convert ProsperRating to an ordered type
rate_order = ['HR','E','D','C','B','A','AA']
ordered_var = pd.api.types.CategoricalDtype(ordered = True, categories = rate_order)
loan.loc[:,'ProsperRating (Alpha)'] = loan.loc[:,'ProsperRating (Alpha)'].astype(ordered_var, copy=True)

# %%
# Convert  Employment status to an ordered type
emp_order = ['Employed','Self-employed','Full-time','Part-time','Retired','Other','Not employed', 'Not available']
ordered_var = pd.api.types.CategoricalDtype(ordered = True, categories = emp_order)
loan.loc[:,'EmploymentStatus'] = loan.loc[:,'EmploymentStatus'].astype(ordered_var, copy=True)

# %% [markdown]
# ### What connection exists between the original loan amount and the borrower APR?
#
# > The borrower's APR has a wide range of values depending on the size of the total loan amount, but the range of APR diminishes as the loan amount rises. Therefore, there is a bad correlation between the borrower's APR and the overall loan amount.

# %% [markdown]
# ### How are the three category traits related to one another?
#
# > The BorrowerRate rises for loans with longer terms at every level of ProsperRating. Given that loans with shorter terms typically have higher interest rates, I would anticipate the opposite. This is a little surprising because it was not at all obvious in the bivariate analysis.

# %% [markdown]
# ### How are the three category traits related to one another; LenderYield vs Borrower APR vs ProsperRating ?
#
# > The lender yield and borrower APR have a straight positive inverse relationship, with the lender yield rising as the borrower pays more interest. Lower borrower interest rates and hence lower lender yields result with higher credit scores.

# %%
# !jupyter nbconvert Prosper_Loan_Data_Analysis_Part2.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Prosper_Loan_Data_Analysis_Part2.ipynb to slides
# [NbConvertApp] Writing 521853 bytes to Prosper_Loan_Data_Analysis_Part2.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Prosper_Loan_Data_Analysis_Part2.slides.html
# Use Control-C to stop this server
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: x-www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: firefox: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: iceweasel: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: seamonkey: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: mozilla: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: epiphany: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: konqueror: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: chromium-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: google-chrome: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'http://127.0.0.1:8000/Prosper_Loan_Data_Analysis_Part2.slides.html'
